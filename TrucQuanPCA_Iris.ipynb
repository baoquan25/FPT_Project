# %% [markdown]
# <a href="https://colab.research.google.com/github/baoquan25/FPT_Project/blob/main/TrucQuanPCA_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#import dataprep
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("iris_PCA.csv")

# %%
data.head()
# Out:
#    principal_component_1  principal_component_2   Id          Species  \
# 0               2.126250              -1.167521   45      Iris-setosa
# 1              -2.308349              -2.617415  132   Iris-virginica
# 2              -2.259983              -1.915027  110   Iris-virginica
# 3              -1.045909              -0.520454   87  Iris-versicolor
# 4               2.390184               0.361181   48      Iris-setosa
#
#    split_field split_dataframe
# 0        0.109        training
# 1        0.326        training
# 2        0.034        training
# 3        0.291        training
# 4        0.240        training

# %%
data.columns
# Out:
# Index(['principal_component_1', 'principal_component_2', 'Id', 'Species',
#        'split_field', 'split_dataframe'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Create a scatter plot using seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(x='principal_component_1', y='principal_component_2', hue='Species', data=data)
plt.show()
